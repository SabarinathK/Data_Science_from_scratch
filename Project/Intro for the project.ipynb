# %% [markdown]
# # Introduction
#
#
# profit and loss
# - price label
#
# data
# - VisiCalc (cmd intreface)
# - Excel (rows and column)
#
# if u have data that good to go with excel
# Big data :
#     - crash
#
# - Python
#     - easy for calculation
#
# big data tools
# - spark
#
#
# - Data load
#     - File u may have
#     - Database
#         - query
#         - sql
#     - Big Data
#         - big querry
#         - pyspark
#
# - Understandin the data
# - data preprocessing (saved model, file)
# - feature engg (saved model, file)
# - Model
#     - train
#     - test
#     - save
#
# - Software Devlopement Cycle
#     - Webapp
#
#
#
#  ## Standards
#  - train dataset
#   - above model pipeline

# %% [markdown]
# # Mushroom Classification
#
#
# Safe to eat or deadly poison?
#
# This dataset includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family Mushroom drawn from The Audubon Society Field Guide to North American Mushrooms (1981). Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended. This latter class was combined with the poisonous one. The Guide clearly states that there is no simple rule for determining the edibility of a mushroom; no rule like "leaflets three, let it be'' for Poisonous Oak and Ivy.
#
#
# # Steps
# 1) Importing libraries
#
# 2) Read Data
#
# 3) Data Preprocessing
#
# 4) Feature Engineering
#
# 5) Model Training

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("mushrooms.csv")
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment
# 0        p         x           s         n       t    p               f  \
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring
# ...

# %%
y =df['class'].copy()
X =df.drop('class',axis=1).copy()

train,test= train_test_split(df, train_size=0.7, shuffle=True , random_state=123)

# %%
train.to_csv("files/train/raw/train.csv",index=False)
test.to_csv("files/test/raw/test.csv",index=False)
